# %% [markdown]
# # <span style="font-family:Georgia; text-align:center;">Cadenas (strings) en Python</span>
# <span style="font-family:Georgia;">
#
# ## ¿Qué es una cadena?
# Una **cadena** (`str`) es una **secuencia inmutable** de caracteres Unicode.
#
# ## Operaciones básicas
# - Longitud: ``len(s)``
# - Concatenación: ``s + t``
# - Repetición: ``s * k``
# - Pertenencia: ``"a" in s``
# - Indexación: ``s[i]``; Slicing: ``s[i:j:k]``

# %%
s = "Hola"
len(s)        # 4
# Out:
# 4

# %%
s + " Mundo"  # "Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
s * 3         # "HolaHolaHola"
# Out:
# 'HolaHolaHola'

# %%
"a" in s      # True
# Out:
# True

# %%
s[1:4]        # "ola"
# Out:
# 'ola'

# %% [markdown]
# <span style="font-family:Georgia;">
#
# ## Limpieza y normalización
# - Quitar espacios: ``s.strip()``, ``s.lstrip()``, `s.rstrip()`
#
# - Mayúsculas/minúsculas: `s.lower()`, `s.upper()`, `s.capitalize()`, `s.title()`, `s.swapcase()`
#
# - Reemplazos: `s.replace(viejo, nuevo, conteo_opcional)`

# %%
"  hola  ".strip()        # "hola"
# Out:
# 'hola'

# %%
"python".upper()          # "PYTHON"
# Out:
# 'PYTHON'

# %%
"hola mundo".title()      # "Hola Mundo"
# Out:
# 'Hola Mundo'

# %%
"aaaa".replace("a", "x", 2)  # "xxaa"
# Out:
# 'xxaa'

# %% [markdown]
# <span style="font-family:Georgia;">
#
# ## Slicing detallado $s[i:j:k]$
#
# - $i$ por defecto $0$; $j$ por defecto $n$; $k$ por defecto $1$.
#
# - Subcadenas con paso: `s[::2]` toma caracteres en posiciones pares.
#
# - Reversa: `s[::-1]`.

# %%
s = "abcdefg"
s[2:5]    # "cde"
# Out:
# 'cde'

# %%
s[:4]     # "abcd"
# Out:
# 'abcd'

# %%
s[::2]    # "aceg"
# Out:
# 'aceg'

# %%
s[::-1]   # "gfedcba"
# Out:
# 'gfedcba'

# %% [markdown]
# <span style="font-family:Georgia;">
#
# ## División y unión
# - Dividir por separador: `s.split(sep=None, maxsplit=-1)`
#
# - Dividir por líneas: `s.splitlines(keepends=False)`
#
# - Particionar en 3 partes: `s.partition(sep)`, `s.rpartition(sep)`
#
# - Unir con separador: `sep.join(iterable_de_cadenas)`

# %%
"uno,dos,tres".split(",")           # ["uno","dos","tres"]
# Out:
# ['uno', 'dos', 'tres']

# %%
"uno\ndos".splitlines()             # ["uno","dos"]
# Out:
# ['uno', 'dos']

# %%
"ruta/archivo.txt".rpartition("/")  # ("ruta", "/", "archivo.txt")
# Out:
# ('ruta', '/', 'archivo.txt')

# %%
"-".join(["2025","08","12"])        # "2025-08-12"
# Out:
# '2025-08-12'

# %% [markdown]
# ## <span style="font-family:Georgia; text-align:center;">Ejercicios</span>
#
# Resuelve los siguientes problemas haciendo:
# - Diagrama de flujo
# - Pseudocódigo
# - Código en Python

# %% [markdown]
# ## <span style="font-family:Georgia; text-align:center;">Ejercicio 1: Contador de vocales</span>
# <span style="font-family:Georgia;">
#
# **Descripción.** Dada una cadena, contar cuántas vocales contiene (a, e, i, o, u), ignorando mayúsculas/minúsculas.
#
# **Entradas/Salidas.** entrada $\to$ `str`; salida $\to$ `int`.
#
# **Pruebas de ejemplo.**
# - “Hola Mundo” $\to 4$
# - “” $\to 0$
# - “xyz” $\to 0$
#
# **Requisitos.** No usar directamente `sum(c in ... for c in s)`.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# entrada <-
# counter = 0
# MIENTRAS hay letras
#     LEER entrada.minuscula
#         SI hay una "a", "e", "i", "o", "u"
#             counter +1
# OTRO :
#     ESCRIBIR counter

# %%
entrada = str (input ())
counter = 0
for i in entrada.lower():
    if ((i == 'a') or (i == 'e') or (i == 'i') or (i =='o') or (i == 'u')) == True:
        counter = counter + 1
print (counter)
# Out:
# 2

# %% [markdown]
# ## <span style="font-family:Georgia; text-align:center;">Ejercicio 2: Máximo de una lista</span>
#
# **Descripción.** Leer $N$ y luego $N$ números; devolver el máximo sin usar `max()`.
#
# **Entradas/Salidas.** entrada $\to$ $N\in\mathbb{N}$ y luego $x_1,\dots,x_N$; salida $\to$ $\max\{x_i\}$.
#
# **Pruebas de ejemplo.**
# - $N=5$, $[3,-1,7,7,2]\to 7$
#
# **Requisitos.** No usar directamente `max()`.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# N = lista []
# MIENTRAS haya numeros
#     comparar uno con el anterior
#     SI uno es mayor al anterior
#         k = nuevo número
#     OTRO
#         k se mantiene igual
# OTRO
#     ESCRIBIR k

# %%
N = str (input())# Hay que escribir la lista de numeros separados por comas. ej: 1,2,3
c = N.split(',')[:1]
for k in c:             # No hallé otra manera de sacar unicamente el primer elemento de N
    k = k
for i in N.split(','):  # se compara un elemento y el anterior
    if ( int(k) < int(i) ):
        k = i 
    elif (int (k) > int (i)):
        k = k
print (k)
# Out:
# 0

# %% [markdown]
# ## <span style="font-family:Georgia; text-align:center;">Ejercicio 3: Validación de contraseña simple</span>
#
# **Descripción.** Validar que una contraseña tenga al menos $8$ caracteres, al menos una mayúscula y al menos un dígito.
#
# **Entradas/Salidas.** entrada $\to$ `str`; salida $\to$ `bool` o mensaje “válida / inválida”.
#
#
# **Pruebas de ejemplo.**
# - “Abcdef12” $\to$ válida
# - “abcdef12” $\to$ inválida (sin mayúscula)
#
# **Extensión.** Devolver lista de reglas incumplidas.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# contraseña =
# SI no hay mayusculas
#     ESCRIBIR debe incluir al menos una mayúscula
# SI es menor a 8 caracteres
#     ESCRIBIR deben ser al menos 8 caracteres
# SI no hay numeros
#     ESCRIBIR debe tener almenos un número
# OTRO
#     ESCRIBIR aceptada

# %%
contraseña = str (input ())
if (contraseña == contraseña.lower()):
    print ('Debe tener al menos una mayuscula')
for i in contraseña:
    if (i in '1234567890'):
        n = 1
    else :
        n = 0
if (n == 0):
        print ('debe tener al menos un número')
if (len(contraseña) < 8):
    print ('debe tener al menos 8 caracteres')
if ((not (contraseña == contraseña.lower())) and (n == 1) and (len(contraseña) > 8)):
    print ('aceptada')
# Out:
# aceptada

# %% [markdown]
# ## <span style="font-family:Georgia; text-align:center;">Ejercicio 4: Conversor base 10 a base b (con 1< b< 17)</span>
#
#
# **Descripción.** Convertir un entero no negativo $n$ en su representación en base $b$.
#
# **Entradas/Salidas.** entrada $\to$ $n\in\mathbb{Z}_{\ge 0}$, $b\in\{2,\dots,16\}$; salida $\to$ `str` con dígitos $0$–$9$ y $A$–$F$.
#
# **Pruebas de ejemplo.**
# - $(255,16)\to\text{"FF"}$
# - $(13,2)\to\text{"1101"}$
#
# **Idea clave.** Repetir: obtener residuo $r=n\bmod b$, dividir $n\leftarrow \lfloor n/b\rfloor$, acumular dígitos y al final invertir.
#
#
# **Pistas para el diagrama de flujo.**
# - Inicio
# - Leer $n,b$
# - Validar $b$ y $n$
# - Caso $n=0$ → devolver “0”
# - Mientras $n>0$:
#   - Calcular $r=n\bmod b$
#   - Mapear $r$ a carácter
#   - Agregar a lista de dígitos
#   - Actualizar $n\leftarrow \lfloor n/b\rfloor$
# - Invertir y unir dígitos
# - Imprimir resultado
# - Fin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# numeros = (n,b)
# SI n = 0
#     ESCRIBIR 0
# MIENTRAS n =/= 0
#     d = n MOD b
#     SI d > 9
#         d = A, B, C, D, E, F, PARA d = 10, 11, 12 ,13 ,14 ,15
#     OTRO
#         d = d
#     STR r + str d
#     n = (n-d)/b
# OTRO:
#     ESCRIBIR r

# %%
numero = str (input ())                 # Se escriben los 2 numeros separados por comas eg: 4,2
lista = numero.split (',')
s = ['A','B','C','D','E','F']
r = ''
n = lista[0]
b = lista[1]
if (n == '0'):
    print (0)
elif ((int (b)) > 0):
    while not (n == 0):
        d = ((int (n)) % (int (b)))
        if (int (d) > 9):
            r = s[( int (d) - 10)] + r
        else :
            r = str (d) + r
        n = ((int(n))- (int(d))) / (int(b))
    print (r)
# Out:
# F
